# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

img = cv2.imread("/Users/yxmas/Desktop/share/xixi/xixi.jpg")

img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

plt.imshow(img)
#plt.axis("off")
plt.show()
